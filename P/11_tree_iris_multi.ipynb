# %% [markdown]
# # DT iris 다중분류 (Multiclass Classification)
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import myutils as my

# %% [markdown]
# ### 데이터 준비

# %%
X_train, X_test, y_train, y_test = my.get_iris()

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5736\253258814.py in <module>
# ----> 1 X_train, X_test, y_train, y_test = my.get_iris()
#       2
#       3 print(X_train.shape, X_test.shape)
#       4 print(y_train.shape, y_test.shape)
#
# AttributeError: module 'myutils' has no attribute 'get_iris'

# %%
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %% [markdown]
# ### 학습

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state=2022)
clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5736\3334348210.py in <module>
#       2
#       3 clf = DecisionTreeClassifier(random_state=2022)
# ----> 4 clf.fit(X_train, y_train)
#       5 clf.score(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ### GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'min_samples_leaf': range(1, 10),
    'max_depth': range(3, 10),
    'min_samples_split': range(3, 10)
}

clf = DecisionTreeClassifier(random_state=2022)

gs = GridSearchCV(clf, params, cv=3, verbose=0)
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(random_state=2022),
#              param_grid={'max_depth': range(3, 10),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(3, 10)})

# %%
gs.best_params_
# Out:
# {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 3}

# %%
gs.best_score_
# Out:
# 0.9666666666666667

# %% [markdown]
# ### 최종

# %%
clf = DecisionTreeClassifier(
    max_depth=3,
    min_samples_leaf=1,
    min_samples_split= 3,
    random_state=2022)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_split=3, random_state=2022)

# %%
from sklearn.tree import plot_tree

plot_tree(clf)
plt.show()
